# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./dataset/train.csv')
test_data = pd.read_csv('./dataset/test.csv')

# %% [markdown]
# Well look at some of the data

# %%
data.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi  price_range
# 0        0             0     1            1
# 1        1             1     0            2
# 2        1             1     0            2
# 3        1             0     0            2
# 4        1             1     0            1
#
# [5 rows x 21 columns]

# %%
data.shape
# Out:
# (2000, 21)

# %% [markdown]
# seeing if there is any null in the data

# %%
data.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %% [markdown]
# What are the data types of the columns

# %%
data.dtypes
# Out:
# battery_power      int64
# blue               int64
# clock_speed      float64
# dual_sim           int64
# fc                 int64
# four_g             int64
# int_memory         int64
# m_dep            float64
# mobile_wt          int64
# n_cores            int64
# pc                 int64
# px_height          int64
# px_width           int64
# ram                int64
# sc_h               int64
# sc_w               int64
# talk_time          int64
# three_g            int64
# touch_screen       int64
# wifi               int64
# price_range        int64
# dtype: object

# %%
data.describe().T.style.background_gradient(cmap = "Blues")
# Out:
# <style type="text/css">
# #T_5a0c4_row0_col0, #T_5a0c4_row1_col0, #T_5a0c4_row1_col1, #T_5a0c4_row1_col2, #T_5a0c4_row1_col3, #T_5a0c4_row1_col4, #T_5a0c4_row1_col5, #T_5a0c4_row1_col6, #T_5a0c4_row1_col7, #T_5a0c4_row2_col0, #T_5a0c4_row2_col1, #T_5a0c4_row2_col2, #T_5a0c4_row2_col3, #T_5a0c4_row2_col4, #T_5a0c4_row2_col5, #T_5a0c4_row2_col6, #T_5a0c4_row2_col7, #T_5a0c4_row3_col0, #T_5a0c4_row3_col1, #T_5a0c4_row3_col2, #T_5a0c4_row3_col3, #T_5a0c4_row3_col4, #T_5a0c4_row3_col5, #T_5a0c4_row3_col6, #T_5a0c4_row3_col7, #T_5a0c4_row4_col0, #T_5a0c4_row4_col1, #T_5a0c4_row4_col2, #T_5a0c4_row4_col3, #T_5a0c4_row4_col4, #T_5a0c4_row4_col5, #T_5a0c4_row4_col6, #T_5a0c4_row5_col0, #T_5a0c4_row5_col1, #T_5a0c4_row5_col2, #T_5a0c4_row5_col3, #T_5a0c4_row5_col4, #T_5a0c4_row5_col5, #T_5a0c4_row5_col6, #T_5a0c4_row5_col7, #T_5a0c4_row6_col0, #T_5a0c4_row7_col0, #T_5a0c4_row7_col1, #T_5a0c4_row7_col2, #T_5a0c4_row7_col3, #T_5a0c4_row7_col4, #T_5a0c4_row7_col5, #T_5a0c4_row7_col6, #T_5a0c4_row7_col7, #T_5a0c4_row8_col0, #T_5a0c4_row9_col0, #T_5a0c4_row9_col1, #T_5a0c4_row9_col2, #T_5a0c4_row9_col3, #T_5a0c4_row9_col4, #T_5a0c4_row9_col5, #T_5a0c4_row9_col6, #T_5a0c4_row9_col7, #T_5a0c4_row10_col0, #T_5a0c4_row10_col3, #T_5a0c4_row11_col0, #T_5a0c4_row11_col3, #T_5a0c4_row12_col0, #T_5a0c4_row13_col0, #T_5a0c4_row14_col0, #T_5a0c4_row14_col2, #T_5a0c4_row15_col0, #T_5a0c4_row15_col1, #T_5a0c4_row15_col2, #T_5a0c4_row15_col3, #T_5a0c4_row15_col4, #T_5a0c4_row15_col5, #T_5a0c4_row15_col6, #T_5a0c4_row16_col0, #T_5a0c4_row17_col0, #T_5a0c4_row17_col1, #T_5a0c4_row17_col2, #T_5a0c4_row17_col3, #T_5a0c4_row17_col4, #T_5a0c4_row17_col5, #T_5a0c4_row17_col6, #T_5a0c4_row17_col7, #T_5a0c4_row18_col0, #T_5a0c4_row18_col1, #T_5a0c4_row18_col2, #T_5a0c4_row18_col3, #T_5a0c4_row18_col4, #T_5a0c4_row18_col5, #T_5a0c4_row18_col6, #T_5a0c4_row18_col7, #T_5a0c4_row19_col0, #T_5a0c4_row19_col1, #T_5a0c4_row19_col2, #T_5a0c4_row19_col3, #T_5a0c4_row19_col4, #T_5a0c4_row19_col5, #T_5a0c4_row19_col6, #T_5a0c4_row19_col7, #T_5a0c4_row20_col0, #T_5a0c4_row20_col1, #T_5a0c4_row20_col2, #T_5a0c4_row20_col3, #T_5a0c4_row20_col4, #T_5a0c4_row20_col5, #T_5a0c4_row20_col6, #T_5a0c4_row20_col7 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_
row2_col3" class="data row2 col3" >0.500000</td>
#       <td id="T_5a0c4_row2_col4" class="data row2 col4" >0.700000</td>
#       <td id="T_5a0c4_row2_col5" class="data row2 col5" >1.500000</td>
#       <td id="T_5a0c4_row2_col6" class="data row2 col6" >2.200000</td>
#       <td id="T_5a0c4_row2_col7" class="data row2 col7" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5a0c4_level0_row3" class="row_heading level0 row3" >dual_sim</th>
#       <td id="T_5a0c4_row3_col0" class="data row3 col0" >2000.000000</td>
#       <td id="T_5a0c4_row3_col1" class="data row3 col1" >0.509500</td>
#       <td i

# %%
data['blue']
# Out:
# 0       0
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1995    1
# 1996    1
# 1997    0
# 1998    0
# 1999    1
# Name: blue, Length: 2000, dtype: int64

# %%
data['blue'] = data['blue'].astype(object)

# %%
data.corr().style.background_gradient(cmap = "Blues")
# Out:
# C:\Users\sharm\AppData\Local\Temp\ipykernel_2452\746379743.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr().style.background_gradient(cmap = "Blues")
# <style type="text/css">
# #T_ef322_row0_col0, #T_ef322_row1_col1, #T_ef322_row2_col2, #T_ef322_row3_col3, #T_ef322_row4_col4, #T_ef322_row5_col5, #T_ef322_row6_col6, #T_ef322_row7_col7, #T_ef322_row8_col8, #T_ef322_row9_col9, #T_ef322_row10_col10, #T_ef322_row11_col11, #T_ef322_row12_col12, #T_ef322_row13_col13, #T_ef322_row14_col14, #T_ef322_row15_col15, #T_ef322_row16_col16, #T_ef322_row17_col17, #T_ef322_row18_col18, #T_ef322_row19_col19 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_ef322_row0_col1, #T_ef322_row0_col16, #T_ef322_row3_col7, #T_ef322_row4_col0, #T_ef322_row6_col9, #T_ef322_row6_col10, #T_ef322_row7_col1, #T_ef322_row8_col15, #T_ef322_row9_col12, #T_ef322_row9_col15, #T_ef322_row11_col14, #T_ef322_row11_col18, #T_ef322_row12_col14, #T_ef322_row12_col15, #T_ef322_row13_col16, #T_ef322_row17_col16, #T_ef322_row18_col13, #T_ef322_row18_col14, #T_ef322_row19_col2, #T_ef322_row19_col13 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_ef322_row0_col2, #T_ef322_row0_col8, #T_ef322_row0_col11, #T_ef322_row0_col13, #T_ef322_row0_col14, #T_ef322_row1_col4, #T_ef322_row1_col11, #T_ef322_row1_col16, #T_ef322_row2_col0, #T_ef322_row2_col3, #T_ef322_row4_col1, #T_ef322_row4_col8, #T_ef322_row4_col15, #T_ef322_row5_col3, #T_ef322_row5_col7, #T_ef322_row5_col8, #T_ef322_row5_col9, #T_ef322_row5_col11, #T_ef322_row5_col17, #T_ef322_row6_col18, #T_ef322_row7_col5, #T_ef322_row7_col13, #T_ef322_row7_col14, #T_ef322_row7_col19, #T_ef322_row9_col5, #T_ef322_row9_col14, #T_ef322_row12_col17, #T_ef322_row13_col6, #T_ef322_row13_col7, #T_ef322_row15_col2, #T_ef322_row15_col4, #T_ef322_row15_col14, #T_ef322_row15_col16, #T_ef322_row15_col18, #T_ef322_row16_col1, #T_ef322_row16_col10, #T_ef322_row16_col15, #T_ef322_row17_col12, #T_ef322_row17_col19, #T_ef322_row18_col6, #T_ef322_row19_col7, #T_ef322_row19_col17 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_
{
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_ef322_row1_col13, #T_ef322_row1_col18

# %%
columns = data.columns[data.any()].tolist()
a = []
b = []
for item in columns:
  a.append(data[item].min())
  b.append(data[item].max())
df = pd.DataFrame(columns, columns = ['Col'])
df['min']= a
df['max'] = b
df
# Out:
#               Col    min     max
# 0   battery_power  501.0  1998.0
# 1            blue    0.0     1.0
# 2     clock_speed    0.5     3.0
# 3        dual_sim    0.0     1.0
# 4              fc    0.0    19.0
# 5          four_g    0.0     1.0
# 6      int_memory    2.0    64.0
# 7           m_dep    0.1     1.0
# 8       mobile_wt   80.0   200.0
# 9         n_cores    1.0     8.0
# 10             pc    0.0    20.0
# 11      px_height    0.0  1960.0
# 12       px_width  500.0  1998.0
# 13            ram  256.0  3998.0
# 14           sc_h    5.0    19.0
# 15           sc_w    0.0    18.0
# 16      talk_time    2.0    20.0
# 17        three_g    0.0     1.0
# 18   touch_screen    0.0     1.0
# 19           wifi    0.0     1.0
# 20    price_range    0.0     3.0

# %%
# get columns whose min is 0 and max is 1
cols = data.columns[(data.min() == 0) & (data.max() == 1)]

# print the selected columns
print(cols)
# Out:
# Index(['blue', 'dual_sim', 'four_g', 'three_g', 'touch_screen', 'wifi'], dtype='object')

# %%
data[cols] = data[cols].astype('object')
print(data[cols].dtypes)
# Out:
# blue            object
# dual_sim        object
# four_g          object
# three_g         object
# touch_screen    object
# wifi            object
# dtype: object

# %% [markdown]
# categorical features

# %%
cat_features = [i for i in data.columns if data.dtypes[i]=='object']
cat_features
# Out:
# ['blue', 'dual_sim', 'four_g', 'three_g', 'touch_screen', 'wifi']

# %% [markdown]
# Numerical Features

# %%
num_features = [i for i in data.columns if data.dtypes[i] in ['int64', 'float']]
num_features[: -1]
num_features
# Out:
# ['battery_power',
#  'clock_speed',
#  'fc',
#  'int_memory',
#  'm_dep',
#  'mobile_wt',
#  'n_cores',
#  'pc',
#  'px_height',
#  'px_width',
#  'ram',
#  'sc_h',
#  'sc_w',
#  'talk_time',
#  'price_range']

# %%
data.loc[:,'price_range'].value_counts()
# Out:
# 1    500
# 2    500
# 3    500
# 0    500
# Name: price_range, dtype: int64

# %%
sns.countplot(x = 'price_range',data = data)
# Out:
# <Axes: xlabel='price_range', ylabel='count'>

# %%
plt.figure(figsize=(20,12))
sns.heatmap(data.corr(),annot = True, linewidth = 2 )
plt.tight_layout()
# Out:
# C:\Users\sharm\AppData\Local\Temp\ipykernel_2452\3124321616.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),annot = True, linewidth = 2 )

# %%
data.drop('price_range', axis=1).corrwith(data.price_range).plot(kind = 'bar', grid = True, figsize=(20,10), 
                                                                 title = 'Correlation with target feature')
# Out:
# C:\Users\sharm\AppData\Local\Temp\ipykernel_2452\1726693767.py:1: FutureWarning: The default value of numeric_only in DataFrame.corrwith is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.drop('price_range', axis=1).corrwith(data.price_range).plot(kind = 'bar', grid = True, figsize=(20,10),
# <Axes: title={'center': 'Correlation with target feature'}>

# %% [markdown]
# # Exploring Numerical Features

# %%
data[num_features].plot(kind='density', layout = (5,3),subplots=True,sharex=False,figsize=(32,16))


plt.show()

# %%
data.hist(figsize=(32,16))
plt.tight_layout()

# %%
fig = plt.figure(2)
sns.distplot(data['fc'])
plt.legend()
# Out:
# C:\Users\sharm\AppData\Local\Temp\ipykernel_2452\3222173388.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['fc'])
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
data
# Out:
#       battery_power blue  clock_speed dual_sim  fc four_g  int_memory  m_dep  \
# 0               842    0          2.2        0   1      0           7    0.6
# 1              1021    1          0.5        1   0      1          53    0.7
# 2               563    1          0.5        1   2      1          41    0.9
# 3               615    1          2.5        0   0      0          10    0.8
# 4              1821    1          1.2        0  13      1          44    0.6
# ...             ...  ...          ...      ...  ..    ...         ...    ...
# 1995            794    1          0.5        1   0      1           2    0.8
# 1996           1965    1          2.6        1   0      0          39    0.2
# 1997           1911    0          0.9        1   1      1          36    0.7
# 1998           1512    0          0.9        0   4      1          46    0.1
# 1999            510    1          2.0        1   5      1          45    0.9
#
#       mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 0           188        2  ...         20       756  2549     9     7
# 1           136        3  ...        905      1988  2631    17     3
# 2           145        5  ...       1263      1716  2603    11     2
# 3           131        6  ...       1216      1786  2769    16     8
# 4           141        2  ...       1208      1212  1411     8     2
# ...         ...      ...  ...        ...       ...   ...   ...   ...
# 1995        106        6  ...       1222      1890   668    13     4
# 1996        187        4  ...        915      1965  2032    11    10
# 1997        108        8  ...        868      1632  3057     9     1
# 1998        145        5  ...        336       670   869    18    10
# 1999        168        6  ...        483       754  3919    19     4
#
#       talk_time  three_g touch_screen wifi price_range
# 0            19        0            0    1           1
# 1             7        1            1    0           2
# 2             9        1            1    0           2
# 3            11        1            0    0           2
# 4            15        1            1    0           1
# ...         ...      ...          ...  ...         ...
# 1995         19        1            1    0           0
# 1996         16        1            1    1           2
# 1997          5        1            1    0           3
# 1998         19        1            1    1           0
# 1999          2        1            1    1           3
#
# [2000 rows x 21 columns]

# %%
fig, ax = plt.subplots(3,3,figsize = (16,8))
sns.countplot(x=num_features[11],hue='price_range', data=data,ax = ax[0,0])
sns.countplot(x=num_features[1],hue='price_range', data=data,ax = ax[0,1])
sns.countplot(x=num_features[2],hue='price_range', data=data,ax = ax[0,2])
sns.countplot(x=num_features[3],hue='price_range', data=data,ax = ax[1,0])
sns.countplot(x=num_features[4],hue='price_range', data=data,ax = ax[1,1])
sns.countplot(x=num_features[5],hue='price_range', data=data,ax = ax[1,2])
sns.countplot(x=num_features[6],hue='price_range', data=data,ax = ax[2,0])
sns.countplot(x=num_features[7],hue='price_range', data=data,ax = ax[2,1])
sns.countplot(x=num_features[13],hue='price_range', data=data,ax = ax[2,2])

fig.tight_layout()

# %%
def kde_numerical_features(column, target) : 
    fig, ax = plt.subplots(figsize = (5,5))
    sns.kdeplot(data[data[target]==1][column], alpha=0.5,shade = True, color="red", label="Price Range", ax = ax)
    sns.kdeplot(data[data[target]==0][column], alpha=0.5,shade = True, color="#fccc79", label=column, ax = ax)
    plt.title('KDE-Plot of {}'.format(column), fontsize = 18)
    ax.set_xlabel(column)
    ax.set_ylabel("Frequency")
    ax.legend()
    plt.show()

# %%
for column in num_features:
    kde_numerical_features(column, "price_range")
# Out:
# C:\Users\sharm\AppData\Local\Temp\ipykernel_2452\2681134636.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[data[target]==1][column], alpha=0.5,shade = True, color="red", label="Price Range", ax = ax)
# C:\Users\sharm\AppData\Local\Temp\ipykernel_2452\2681134636.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[data[target]==0][column], alpha=0.5,shade = True, color="#fccc79", label=column, ax = ax)
# C:\Users\sharm\AppData\Local\Temp\ipykernel_2452\2681134636.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[data[target]==1][column], alpha=0.5,shade = True, color="red", label="Price Range", ax = ax)
# C:\Users\sharm\AppData\Local\Temp\ipykernel_2452\2681134636.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[data[target]==0][column], alpha=0.5,shade = True, color="#fccc79", label=column, ax = ax)
# C:\Users\sharm\AppData\Local\Temp\ipykernel_2452\2681134636.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[data[target]==1][column], alpha=0.5,shade = True, color="red", label="Price Range", ax = ax)
# C:\Users\sharm\AppData\Local\Temp\ipykernel_2452\2681134636.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[data[target]==0][column], alpha=0.5,shade = True, color="#fccc79", label=column, ax = ax)
# C:\Users\sharm\AppData\Local\Temp\ipykernel_2452\2681134636.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[data[target]==1][column], alpha=0.5,shade = True, color="red", label="Price Range", ax = ax)
# C:\Users\sharm\AppData\Local\Temp\ipykernel_2452\2681134636.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[data[target]==0][column], alpha=0.5,shade = True, color="#fccc79", label=column, ax = ax)
# C:\Users\sharm\AppData\Local\Temp\ipykernel_2452\2681134636.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[data[target]==1][column], alpha=0.5,shade = True, color="red", label="Price Range", ax = ax)
# C:\Users\sharm\AppData\Local\Temp\ipykernel_2452\2681134636.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[data[target]==0][column], alpha=0.5,shade = True, color="#fccc79", label=column, ax = ax)
# C:\Users\sharm\AppData\Local\Temp\ipykernel_2452\2681134636.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[data[target]==1][column], alpha=0.5,shade = True, color="red", label="Price Range", ax = ax)
# C:\Users\sharm\AppData\Local\Temp\ipykernel_2452\2681134636.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[data[target]==0][column], alpha=0.5,shade = True, color="#fccc79", label=column, ax = ax)
# C:\Users\sharm\AppData\Local\Temp\ipykernel_2452\2681134636.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[data[target]==1][column], alpha=0.5,shade = True, color="red", label="Price Range", ax = ax)
# C:\Users\sharm\AppData\Local\Temp\ipykernel_2452\2681134636.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[data[target]==0][column], alpha=0.5,shade = True, color="#fccc79", label=column, ax = ax)
# C:\Users\sharm\AppData\Local\Temp\ipykernel_2452\2681134636.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[data[target]==1][column], alpha=0.5,shade = True, color="red", label="Price Range", ax = ax)
# C:\Users\sharm\AppData\Local\Temp\ipykernel_2452\2681134636.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[data[target]==0][column], alpha=0.5,shade = True, color="#fccc79", label=column, ax = ax)
# C:\Users\sharm\AppData\Local\Temp\ipykernel_2452\2681134636.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[data[target]==1][column], alpha=0.5,shade = True, color="red", label="Price Range", ax = ax)
# C:\Users\sharm\AppData\Local\Temp\ipykernel_2452\2681134636.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[data[target]==0][column], alpha=0.5,shade = True, color="#fccc79", label=column, ax = ax)
# C:\Users\sharm\AppData\Local\Temp\ipykernel_2452\2681134636.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[data[target]==1][column], alpha=0.5,shade = True, color="red", label="Price Range", ax = ax)
# C:\Users\sharm\AppData\Local\Temp\ipykernel_2452\2681134636.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[data[target]==0][column], alpha=0.5,shade = True, color="#fccc79", label=column, ax = ax)
# C:\Users\sharm\AppData\Local\Temp\ipykernel_2452\2681134636.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[data[target]==1][column], alpha=0.5,shade = True, color="red", label="Price Range", ax = ax)
# C:\Users\sharm\AppData\Local\Temp\ipykernel_2452\2681134636.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[data[target]==0][column], alpha=0.5,shade = True, color="#fccc79", label=column, ax = ax)
# C:\Users\sharm\AppData\Local\Temp\ipykernel_2452\2681134636.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[data[target]==1][column], alpha=0.5,shade = True, color="red", label="Price Range", ax = ax)
# C:\Users\sharm\AppData\Local\Temp\ipykernel_2452\2681134636.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[data[target]==0][column], alpha=0.5,shade = True, color="#fccc79", label=column, ax = ax)
# C:\Users\sharm\AppData\Local\Temp\ipykernel_2452\2681134636.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[data[target]==1][column], alpha=0.5,shade = True, color="red", label="Price Range", ax = ax)
# C:\Users\sharm\AppData\Local\Temp\ipykernel_2452\2681134636.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[data[target]==0][column], alpha=0.5,shade = True, color="#fccc79", label=column, ax = ax)
# C:\Users\sharm\AppData\Local\Temp\ipykernel_2452\2681134636.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[data[target]==1][column], alpha=0.5,shade = True, color="red", label="Price Range", ax = ax)
# C:\Users\sharm\AppData\Local\Temp\ipykernel_2452\2681134636.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[data[target]==0][column], alpha=0.5,shade = True, color="#fccc79", label=column, ax = ax)
# C:\Users\sharm\AppData\Local\Temp\ipykernel_2452\2681134636.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[data[target]==1][column], alpha=0.5,shade = True, color="red", label="Price Range", ax = ax)
# C:\Users\sharm\AppData\Local\Temp\ipykernel_2452\2681134636.py:3: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data[data[target]==1][column], alpha=0.5,shade = True, color="red", label="Price Range", ax = ax)
# C:\Users\sharm\AppData\Local\Temp\ipykernel_2452\2681134636.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[data[target]==0][column], alpha=0.5,shade = True, color="#fccc79", label=column, ax = ax)
# C:\Users\sharm\AppData\Local\Temp\ipykernel_2452\2681134636.py:4: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data[data[target]==0][column], alpha=0.5,shade = True, color="#fccc79", label=column, ax = ax)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Now for the algorithm implementation

# %%
final_df = data
X = final_df.drop(columns=['price_range'],axis=1)
y = final_df['price_range']

# %% [markdown]
# Scaling data to make good

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

standardizer = StandardScaler()
X_scaled = standardizer.fit_transform(X)

# %%
X_scaled
# Out:
# array([[-0.90259726, -0.9900495 ,  0.83077942, ..., -1.78686097,
#         -1.00601811,  0.98609664],
#        [-0.49513857,  1.0100505 , -1.2530642 , ...,  0.55964063,
#          0.99401789, -1.01409939],
#        [-1.5376865 ,  1.0100505 , -1.2530642 , ...,  0.55964063,
#          0.99401789, -1.01409939],
#        ...,
#        [ 1.53077336, -0.9900495 , -0.76274805, ...,  0.55964063,
#          0.99401789, -1.01409939],
#        [ 0.62252745, -0.9900495 , -0.76274805, ...,  0.55964063,
#          0.99401789,  0.98609664],
#        [-1.65833069,  1.0100505 ,  0.58562134, ...,  0.55964063,
#          0.99401789,  0.98609664]])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
RANDOM_STATE = 55

# %%
X_train, X_val, y_train, y_val = train_test_split(X_scaled, y, test_size = 0.25, random_state=42)

# %%
""" print(f"target proportion: {sum(y_train)/len(y_train)}") """
y_train
# Out:
# 1738    1
# 548     2
# 936     3
# 1389    0
# 1607    2
#        ..
# 1130    3
# 1294    0
# 860     2
# 1459    3
# 1126    1
# Name: price_range, Length: 1500, dtype: int64

# %%
min_samples_split_list = [2,10,30,50,100,200,300,700] #integer gives actual sample quantity
max_depth_list = [1,2,3,4,8,16,32,64,None] # none means that there is no depth limit
n_estimators_list = [10,50,100,200,300,400,500]

# %% [markdown]
# # Finding hyperparameter minsamplesforsplitting

# %%
import matplotlib.pyplot as plt
accuracy_list_train = []
accuracy_list_val = []

for min_samples_split in min_samples_split_list:
    model = RandomForestClassifier(min_samples_split= min_samples_split, random_state = 42).fit(X_train, y_train)
    predictions_train = model.predict(X_train)
    predictions_val = model.predict(X_val)
    accuracy_train = accuracy_score(predictions_train,y_train)
    accuracy_val = accuracy_score(predictions_val, y_val)
    accuracy_list_train.append(accuracy_train)
    accuracy_list_val.append(accuracy_val)

plt.title("Train x Validation metrices")
plt.xlabel("min_samples_split")
plt.ylabel("accuracy")
plt.xticks(ticks=range(len(min_samples_split_list)), labels=min_samples_split_list)
plt.plot(accuracy_list_train)
plt.plot(accuracy_list_val)
plt.legend(["Train", "Validation"])

# %% [markdown]
# # Increasing min_samples_split
#
# Reduces the overfitting drastically train accuracy and test accuracy is near so min_sample_split = 200

# %% [markdown]
# # Max_depth hyperparameter

# %%
accuracy_list_train = []
accuracy_list_val = []
for max_depth in max_depth_list:
    # You can fit the model at the same time you define it, because the fit function returns the fitted estimator.
    model = DecisionTreeClassifier(max_depth = max_depth,
                                   random_state = 42).fit(X_train,y_train) 
    predictions_train = model.predict(X_train) ## The predicted values for the train dataset
    predictions_val = model.predict(X_val) ## The predicted values for the test dataset
    accuracy_train = accuracy_score(predictions_train,y_train)
    accuracy_val = accuracy_score(predictions_val,y_val)
    accuracy_list_train.append(accuracy_train)
    accuracy_list_val.append(accuracy_val)

plt.title('Train x Validation metrics')
plt.xlabel('max_depth')
plt.ylabel('accuracy')
plt.xticks(ticks = range(len(max_depth_list )),labels=max_depth_list)
plt.plot(accuracy_list_train)
plt.plot(accuracy_list_val)
plt.legend(['Train','Validation'])

# %% [markdown]
# # max_depth = 4  ideal case

# %% [markdown]
# # n_estimators

# %%
accuracy_list_train = []
accuracy_list_val = []
for n_estimators in n_estimators_list:
    model = RandomForestClassifier(n_estimators = n_estimators, random_state = 42).fit(X_train, y_train)
    predictions_train = model.predict(X_train)
    predictions_val = model.predict(X_val)
    accuracy_train = accuracy_score(predictions_train, y_train)
    accuracy_val = accuracy_score(predictions_val, y_val)
    accuracy_list_train.append(accuracy_train)
    accuracy_list_val.append(accuracy_val)
    
plt.title('Train x Validation metrics')
plt.xlabel('n_estimators')
plt.ylabel('accuracy')
plt.xticks(ticks = range(len(n_estimators_list )),labels=n_estimators_list)
plt.plot(accuracy_list_train)
plt.plot(accuracy_list_val)
plt.legend(['Train','Validation'])

# %% [markdown]
# # n_estimators = 200

# %%
random_forest_model = RandomForestClassifier(n_estimators = 200, max_depth = 4 , min_samples_split = 200).fit(X_train, y_train)

# %%
print(f"Metrics train:\n\tAccuracy score: {accuracy_score(random_forest_model.predict(X_train),y_train):.4f}\nMetrics test:\n\tAccuracy score: {accuracy_score(random_forest_model.predict(X_val),y_val):.4f}")
# Out:
# Metrics train:
# 	Accuracy score: 0.8513
# Metrics test:
# 	Accuracy score: 0.8280

# %% [markdown]
# # XG Boost

# %%
from xgboost import XGBClassifier
n = int(len(X_train)*0.8)

# %%
X_train_fit, X_train_eval, y_train_fit, y_train_eval = X_train[:n], X_train[n:], y_train[:n], y_train[n:]

# %%
xgb_model = XGBClassifier(n_estimators = 500, learning_rate = 0.1,verbosity = 1, random_state=42)
xgb_model.fit(X_train_fit,y_train_fit, eval_set = [(X_train_eval,y_train_eval)], early_stopping_rounds = 10)
# Out:
# [0]	validation_0-mlogloss:1.25103
# [1]	validation_0-mlogloss:1.13988
# [2]	validation_0-mlogloss:1.04786
# [3]	validation_0-mlogloss:0.97084
# [4]	validation_0-mlogloss:0.90192
# [5]	validation_0-mlogloss:0.84403
# [6]	validation_0-mlogloss:0.79359
# [7]	validation_0-mlogloss:0.74984
# [8]	validation_0-mlogloss:0.70858
# [9]	validation_0-mlogloss:0.67425
# [10]	validation_0-mlogloss:0.64047
# [11]	validation_0-mlogloss:0.61126
# [12]	validation_0-mlogloss:0.58590
# [13]	validation_0-mlogloss:0.56325
# [14]	validation_0-mlogloss:0.54165
# [15]	validation_0-mlogloss:0.52047
# [16]	validation_0-mlogloss:0.50285
# [17]	validation_0-mlogloss:0.48392
# [18]	validation_0-mlogloss:0.46668
# [19]	validation_0-mlogloss:0.45120
# [20]	validation_0-mlogloss:0.43788
# [21]	validation_0-mlogloss:0.42460
# [22]	validation_0-mlogloss:0.41492
# [23]	validation_0-mlogloss:0.40506
# C:\Users\sharm\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [24]	validation_0-mlogloss:0.39454
# [25]	validation_0-mlogloss:0.38304
# [26]	validation_0-mlogloss:0.37449
# [27]	validation_0-mlogloss:0.36585
# [28]	validation_0-mlogloss:0.35891
# [29]	validation_0-mlogloss:0.35187
# [30]	validation_0-mlogloss:0.34495
# [31]	validation_0-mlogloss:0.33790
# [32]	validation_0-mlogloss:0.33256
# [33]	validation_0-mlogloss:0.32713
# [34]	validation_0-mlogloss:0.32172
# [35]	validation_0-mlogloss:0.31570
# [36]	validation_0-mlogloss:0.31125
# [37]	validation_0-mlogloss:0.30677
# [38]	validation_0-mlogloss:0.30257
# [39]	validation_0-mlogloss:0.29842
# [40]	validation_0-mlogloss:0.29334
# [41]	validation_0-mlogloss:0.28943
# [42]	validation_0-mlogloss:0.28652
# [43]	validation_0-mlogloss:0.28407
# [44]	validation_0-mlogloss:0.28150
# [45]	validation_0-mlogloss:0.27889
# [46]	validation_0-mlogloss:0.27577
# [47]	validation_0-mlogloss:0.27413
# [48]	validation_0-mlogloss:0.27264
# [49]	validation_0-mlogloss:0.27043
# [50]	validation_0-mlogloss:0.26850
# [51]	validation_0-mlogloss:0.26743
# [52]	validation_0-mlogloss:0.26555
# [53]	validation_0-mlogloss:0.26448
# [54]	validation_0-mlogloss:0.26184
# [55]	validation_0-mlogloss:0.26132
# [56]	validation_0-mlogloss:0.25989
# [57]	validation_0-mlogloss:0.25820
# [58]	validation_0-mlogloss:0.25697
# [59]	validation_0-mlogloss:0.25563
# [60]	validation_0-mlogloss:0.25441
# [61]	validation_0-mlogloss:0.25233
# [62]	validation_0-mlogloss:0.25132
# [63]	validation_0-mlogloss:0.25039
# [64]	validation_0-mlogloss:0.24911
# [65]	validation_0-mlogloss:0.24858
# [66]	validation_0-mlogloss:0.24712
# [67]	validation_0-mlogloss:0.24544
# [68]	validation_0-mlogloss:0.24512
# [69]	validation_0-mlogloss:0.24439
# [70]	validation_0-mlogloss:0.24298
# [71]	validation_0-mlogloss:0.24256
# [72]	validation_0-mlogloss:0.24178
# [73]	validation_0-mlogloss:0.24111
# [74]	validation_0-mlogloss:0.24010
# [75]	validation_0-mlogloss:0.23955
# [76]	validation_0-mlogloss:0.23930
# [77]	validation_0-mlogloss:0.23809
# [78]	validation_0-mlogloss:0.23755
# [79]	validation_0-mlogloss:0.23701
# [80]	validation_0-mlogloss:0.23685
# [81]	validation_0-mlogloss:0.23685
# [82]	validation_0-mlogloss:0.23749
# [83]	validation_0-mlogloss:0.23733
# [84]	validation_0-mlogloss:0.23723
# [85]	validation_0-mlogloss:0.23664
# [86]	validation_0-mlogloss:0.23643
# [87]	validation_0-mlogloss:0.23666
# [88]	validation_0-mlogloss:0.23678
# [89]	validation_0-mlogloss:0.23674
# [90]	validation_0-mlogloss:0.23703
# [91]	validation_0-mlogloss:0.23652
# [92]	validation_0-mlogloss:0.23680
# [93]	validation_0-mlogloss:0.23639
# [94]	validation_0-mlogloss:0.23600
# [95]	validation_0-mlogloss:0.23655
# [96]	validation_0-mlogloss:0.23622
# [97]	validation_0-mlogloss:0.23610
# [98]	validation_0-mlogloss:0.23603
# [99]	validation_0-mlogloss:0.23606
# [100]	validation_0-mlogloss:0.23508
# [101]	validation_0-mlogloss:0.23517
# [102]	validation_0-mlogloss:0.23511
# [103]	validation_0-mlogloss:0.23511
# [104]	validation_0-mlogloss:0.23493
# [105]	validation_0-mlogloss:0.23450
# [106]	validation_0-mlogloss:0.23481
# [107]	validation_0-mlogloss:0.23531
# [108]	validation_0-mlogloss:0.23558
# [109]	validation_0-mlogloss:0.23564
# [110]	validation_0-mlogloss:0.23610
# [111]	validation_0-mlogloss:0.23628
# [112]	validation_0-mlogloss:0.23611
# [113]	validation_0-mlogloss:0.23573
# [114]	validation_0-mlogloss:0.23621
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=500, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...)

# %%
xgb_model.best_iteration
# Out:
# 105

# %%
print(f"Metrics train:\n\tAccuracy score: {accuracy_score(xgb_model.predict(X_train),y_train):.4f}\nMetrics test:\n\tAccuracy score: {accuracy_score(xgb_model.predict(X_val),y_val):.4f}")
# Out:
# Metrics train:
# 	Accuracy score: 0.9773
# Metrics test:
# 	Accuracy score: 0.8940

# %% [markdown]
# # logistic Regression

# %%
logreg = LogisticRegression()

logreg.fit(X_train,y_train)
y_pred = logreg.predict(X_val)

# %%
import joblib
joblib.dump(logreg,r'./dataset/lg.sav')
# Out:
# ['./dataset/lg.sav']

# %%
print(classification_report(y_val,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97       132
#            1       0.92      0.98      0.95       118
#            2       0.99      0.91      0.95       120
#            3       0.96      0.99      0.97       130
#
#     accuracy                           0.96       500
#    macro avg       0.96      0.96      0.96       500
# weighted avg       0.96      0.96      0.96       500

# %%
print(accuracy_score(y_val,y_pred))
# Out:
# 0.962

# %%
cnf_matrix = metrics.confusion_matrix(y_val, y_pred)
cnf_matrix

class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)

# create heatmap
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()

plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 427.9555555555555, 'Predicted label')

# %% [markdown]
# # Linear SVC

# %%
linear_svc = LinearSVC()

# %%
linear_svc.fit(X_train,y_train)
# Out:
# C:\Users\sharm\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# LinearSVC()

# %%
y_pred = model.predict(X_val)

# %%
print(classification_report(y_val,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94       132
#            1       0.82      0.87      0.84       118
#            2       0.82      0.80      0.81       120
#            3       0.92      0.90      0.91       130
#
#     accuracy                           0.88       500
#    macro avg       0.88      0.88      0.88       500
# weighted avg       0.88      0.88      0.88       500

# %%
print(accuracy_score(y_val,y_pred))
# Out:
# 0.878

# %%
cnf_matrix = metrics.confusion_matrix(y_val, y_pred)
cnf_matrix

class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)

# create heatmap
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()

plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 427.9555555555555, 'Predicted label')

# %% [markdown]
# # KNeighbour Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

clf = KNeighborsClassifier(n_neighbors= 5)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_val)

# acc = accuracy_score(y_val,y_pred)

# print(acc)
print(classification_report(y_val,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.71      0.70       132
#            1       0.36      0.45      0.40       118
#            2       0.37      0.38      0.38       120
#            3       0.73      0.51      0.60       130
#
#     accuracy                           0.52       500
#    macro avg       0.54      0.51      0.52       500
# weighted avg       0.54      0.52      0.52       500

# %% [markdown]
# # CAT Boosting

# %%
import catboost as cb
cb_clf = cb.CatBoostClassifier()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 import catboost as cb
#       2 cb_clf = cb.CatBoostClassifier()
#
# ModuleNotFoundError: No module named 'catboost'

# %%
cb_clf.fit(X_train,y_train)

# %%
y_pred = model.predict(X_val)

# %%
print(classification_report(y_val,y_pred))
print(accuracy_score(y_val,y_pred))

# %%
cnf_matrix = metrics.confusion_matrix(y_val, y_pred)
cnf_matrix

class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)

# create heatmap
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()

plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')

# %% [markdown]
# # LGBM Classifier

# %%
from lightgbm import LGBMClassifier
clf = LGBMClassifier()
clf.fit(X_train,y_train)
y_pred = clf.predict(X_val)

print(classification_report(y_val,y_pred))

# %%
cnf_matrix = metrics.confusion_matrix(y_val, y_pred)
cnf_matrix

class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)

# create heatmap
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()

plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
